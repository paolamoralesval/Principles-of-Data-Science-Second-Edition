# %%
import numpy as np
import pandas as pd

# create user preferences
user_pref = np.array([5, 1, 3])
print(user_pref)
# Out:
# [5 1 3]

# %%
# create a random movie matrix of 10,000 movies
movies = np.random.randint(5,size=(3,1000))+1
movies2 = pd.DataFrame(movies)
movies2.describe()
# Out:
#             0         1         2    3         4         5         6    \
# count  3.000000  3.000000  3.000000  3.0  3.000000  3.000000  3.000000
# mean   2.000000  2.666667  2.666667  4.0  3.666667  1.666667  1.666667
# std    1.732051  2.081666  1.527525  1.0  0.577350  1.154701  1.154701
# min    1.000000  1.000000  1.000000  3.0  3.000000  1.000000  1.000000
# 25%    1.000000  1.500000  2.000000  3.5  3.500000  1.000000  1.000000
# 50%    1.000000  2.000000  3.000000  4.0  4.000000  1.000000  1.000000
# 75%    2.500000  3.500000  3.500000  4.5  4.000000  2.000000  2.000000
# max    4.000000  5.000000  4.000000  5.0  4.000000  3.000000  3.000000
#
#             7    8         9    ...  990       991       992       993  \
# count  3.000000  3.0  3.000000  ...  3.0  3.000000  3.000000  3.000000
# mean   2.666667  3.0  3.666667  ...  3.0  3.666667  2.666667  3.000000
# std    2.081666  2.0  2.309401  ...  1.0  0.577350  0.577350  1.732051
# min    1.000000  1.0  1.000000  ...  2.0  3.000000  2.000000  1.000000
# 25%    1.500000  2.0  3.000000  ...  2.5  3.500000  2.500000  2.500000
# 50%    2.000000  3.0  5.000000  ...  3.0  4.000000  3.000000  4.000000
# 75%    3.500000  4.0  5.000000  ...  3.5  4.000000  3.000000  4.000000
# max    5.000000  5.0  5.000000  ...  4.0  4.000000  3.000000  4.000000
#
#             994       995  996  997       998       999
# count  3.000000  3.000000  3.0  3.0  3.000000  3.000000
# mean   3.666667  3.666667  2.0  3.0  3.000000  4.333333
# std    2.309401  1.527525  1.0  1.0  1.732051  1.154701
# min    1.000000  2.000000  1.0  2.0  2.000000  3.000000
# 25%    3.000000  3.000000  1.5  2.5  2.000000  4.000000
# 50%    5.000000  4.000000  2.0  3.0  2.000000  5.000000
# 75%    5.000000  4.500000  2.5  3.5  3.500000  5.000000
# max    5.000000  5.000000  3.0  4.0  5.000000  5.000000
#
# [8 rows x 1000 columns]

# %%
# Note that the randint will make random integers from 0-4
# so I added a 1 at the end to increase the scale from 1-5

print(user_pref.shape) # (1, 3)

print(movies.shape)    # (3, 1000)

# np.dot does both dot products and matrix multiplication
recs = np.dot(user_pref, movies)

import time

for i in (10000, 100000, 1000000, 10000000, 100000000):
    movies = np.random.randint(5,size=(3,i))+1
    now = time.time()
    np.dot(user_pref, movies)
    print (time.time() - now), "seconds to run", i, "movies"
# Out:
# (3,)
# (3, 1000)
# 0.0
# 0.0009975433349609375
# 0.0069811344146728516
# 0.060585737228393555
# 0.8092129230499268
